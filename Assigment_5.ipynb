# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
#api_key = "AJVHRXRG22AWU7VLQ52QVZFKT"
#url = f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Kyiv/next7days?unitGroup=us&elements=temp%2Cwindspeed&include=alerts%2Chours&key={api_key}&contentType=json"
url_1 = "https://api.open-meteo.com/v1/forecast?latitude=52.52&longitude=13.41&hourly=temperature_2m,wind_speed_80m"
data = requests.get(url_1)
df = pd.DataFrame(data)
temperature = 
display(df)
# Out:
#                                                     0
# 0   b'{"latitude":52.52,"longitude":13.419998,"gen...
# 1   b'_abbreviation":"GMT","elevation":38.0,"hourl...
# 2   b'{"time":["2025-06-21T00:00","2025-06-21T01:0...
# 3   b'-06-21T06:00","2025-06-21T07:00","2025-06-21...
# 4   b'"2025-06-21T13:00","2025-06-21T14:00","2025-...
# 5   b':00","2025-06-21T20:00","2025-06-21T21:00","...
# 6   b'22T02:00","2025-06-22T03:00","2025-06-22T04:...
# 7   b'5-06-22T09:00","2025-06-22T10:00","2025-06-2...
# 8   b',"2025-06-22T16:00","2025-06-22T17:00","2025...
# 9   b'2:00","2025-06-22T23:00","2025-06-23T00:00",...
# 10  b'-23T05:00","2025-06-23T06:00","2025-06-23T07...
# 11  b'25-06-23T12:00","2025-06-23T13:00","2025-06-...
# 12  b'","2025-06-23T19:00","2025-06-23T20:00","202...
# 13  b'01:00","2025-06-24T02:00","2025-06-24T03:00"...
# 14  b'6-24T08:00","2025-06-24T09:00","2025-06-24T1...
# 15  b'025-06-24T15:00","2025-06-24T16:00","2025-06...
# ...
