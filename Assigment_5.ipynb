# %%
import requests
import pandas as pd
url = "https://api.open-meteo.com/v1/forecast?latitude=50.4547&longitude=30.5238&hourly=temperature_2m,wind_speed_80m&timezone=auto"
data = requests.get(url).json()
time = pd.Series(data["hourly"]["time"])
temperature = pd.Series(data["hourly"]["temperature_2m"])
wind_speed = pd.Series(data["hourly"]["wind_speed_80m"])
dict = {
   "temperature": temperature,
    "wind_speed": wind_speed,
    "time":time,
} 
is_wind_speed_more_avg = pd.Series([dict["wind_speed"] > (sum(dict["wind_speed"]) / len(dict["wind_speed"]))])[0]
dict["is_wind_speed_more_avg"] = is_wind_speed_more_avg
df = pd.DataFrame(dict)
display(df)

print("A number of hours when wind speed more than average wind speed :", sum(df["is_wind_speed_more_avg"]), end="\n\n")

print("min for 3 days :", min(df["temperature"].loc[:71]))
print("max for 3 days :", max(df["temperature"].loc[:71]))
print("avg for 3 days :", sum(df["temperature"].loc[:71]) / 72)
# Out:
#      temperature  wind_speed              time  is_wind_speed_more_avg
# 0           14.6        18.3  2025-06-22T00:00                   False
# 1           13.8        17.3  2025-06-22T01:00                   False
# 2           13.8        19.8  2025-06-22T02:00                    True
# 3           13.1        20.5  2025-06-22T03:00                    True
# 4           12.9        20.9  2025-06-22T04:00                    True
# ..           ...         ...               ...                     ...
# 163         17.6        16.2  2025-06-28T19:00                   False
# 164         17.1        11.5  2025-06-28T20:00                   False
# 165         16.6         9.2  2025-06-28T21:00                   False
# 166         15.9        11.4  2025-06-28T22:00                   False
# 167         15.1        16.1  2025-06-28T23:00                   False
#
# [168 rows x 4 columns]
# A number of days when wind speed more than average wind speed : 101
#
# min for 3 days : 11.3
# max for 3 days : 24.1
# avg for 3 days : 17.05138888888889
